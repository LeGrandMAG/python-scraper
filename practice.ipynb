# %%
import requests
from pprint import pprint
from bs4 import BeautifulSoup
r = requests.get('https://www.bizcongo.com/annonce-particulier').text

# %%
print(r)
# Out:
# <!-- THEME DEBUG -->
# <!-- CALL: theme('html') -->
# <!-- FILE NAME SUGGESTIONS:
#    * html--annonce-particulier.tpl.php
#    x html.tpl.php
# -->
# <!-- BEGIN OUTPUT from 'sites/all/themes/bizcongo/templates/system/html.tpl.php' -->
# <!DOCTYPE html>
# <html lang="fr" dir="ltr">
# <head>
#     <meta charset="utf-8">
#     <meta  name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">
#     <meta name="google" content="notranslate">
#     <title>Petites Annonces | Bizcongo</title>
#     <link rel="shortcut icon" href="https://www.bizcongo.com/sites/all/themes/bizcongo/favicon.ico" type="image/vnd.microsoft.icon" />
# ...

# %%
soup = BeautifulSoup(r, 'lxml')

# %%
# Out:
# [<div id="loading">
# <img alt="Loading..." id="loading-image" src="/sites/all/themes/bizcongo/images/ajax-loader-biz.gif"/>
# </div>, <div id="page-wrapper">
# <div id="page">
# <!--Header Top-->
# <div class="header-top-bar">
# <div class="container">
# <div class="row">
# <div class="block-left">
# <a href="/user/login?destination=annonce-particulier" id="login"><i class="fa fa-user"></i>Espace privé</a>
# <span class="sparateur-header">|</span>
# <div class="panier">
# <!-- THEME DEBUG -->
# <!-- CALL: theme('panier') -->
# <!-- BEGIN OUTPUT from 'sites/all/modules/custom/mod_bizcongo/templates/blocks/block-panier.tpl.php' -->
# <div class="menu-connexion">
# <a href="#" id="panier">
# <span class="panier-count">
# <i class="fa fa-shopping-cart"></i>
#       (0)
#     </span>
#     Panier    <span class="fa fa-chevron-down"></span>
# </a>
# <div class="corp-panier">
# <div class="non-produit">
# <p>Il n'y a aucun produit dans votre panier</p>
# </div>
# </div>
# </div>
# ...

# %%
print(results.prettify())
# Out:
# <div class="f">
#  <div id="viewport">
#   <div class="g h" id="MChromeHeader">
#    <div class="i j" id="header">
#     <h1 style="display:block;height:0;overflow:hidden;position:absolute;width:0;padding:0">
#      Facebook
#     </h1>
#     <a href="/home.php">
#      <img alt="facebook" class="k l" height="16" src="https://static.xx.fbcdn.net/rsrc.php/v3/y8/r/k97pj8-or6s.png" width="77"/>
#     </a>
#    </div>
#   </div>
#   <div id="objects_container">
#    <div class="e" id="root">
#     <table class="m">
#      <tbody>
#       <tr>
#        <td class="n">
#         <div>
#          <div class="o">
#           <div class="p">
#            <div class="q">
#             <img class="r l" height="32" src="https://static.xx.fbcdn.net/rsrc.php/v3/yz/r/BlCVezh8Ti2.png" width="32"/>
#             <h2 class="s">
#              Facebook 그룹
#             </h2>
#             <h3 class="t">
#              회원님의 관심사와 일치하는 그룹을 찾아보세요.
#             </h3>
# ...
